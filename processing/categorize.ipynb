# %%
import os
import numpy as np
import pandas as pd
from concurrent.futures import ThreadPoolExecutor
import json
from pathlib import Path
from dotenv import load_dotenv
from openai import OpenAI

# Load environment variables
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

# %%
# Load in transaction data
data_folder = Path.cwd().parent / 'data'
transaction_folder = data_folder / 'transactions'
reports_folder = data_folder / 'reports'
transactions_df = pd.read_csv(transaction_folder / "merged_transactions.csv")

# %%
# Load in category dictionary, create if there is none
dictionary_file_path = reports_folder / 'category_dict.json'

# Check if the file path exists
if not dictionary_file_path.exists():
    category_dict = {}
    with open(dictionary_file_path, 'w') as file:
        json.dump(category_dict,file)
        print(f"Created category dictionary saved to {dictionary_file_path}")
else:
    with open(dictionary_file_path, 'r') as file:
        category_dict = json.load(file)

# %%
def process_chunk(chunk, api_key):
    chunk_counter = 1

    category_dict = {}
    # For each description in the chunk, get the category classification and store in dictionary 
    for element in chunk:
        start_time = time.time()
        print(f"Processing chunk number: {chunk_counter}...")
        description = str(element)
        category = classify_transaction(description, api_key)
        category_dict[description] = category
        print(f"Processed chunk number: {chunk_counter}")
        chunk_counter += 1 
        end_time = time.time()
        process_time = end_time - start_time
        print(f"Processing time for chunk {chunk_counter}: {process_time}")

    return category_dict

# %%
def classify_transaction(description, api_key):
    prompt = f"""
    Classify this description into a category:
    - Description: {description}
    - Categories: Housing, Utilities, Groceries, Transportation, Insurance, Debt Payments, Dining & Takeout, Entertainment,
                 Shopping, Subscriptions & Memberships, Personal Care, Hobbies & Recreation, Medical & Healthcare, Fitness,
                Self-Care, Savings, Investments, Education & Self-Development, Business Expenses, Taxes, Travel,
                and Gifts & Donations..

    Provide only the category name
    """

    client = OpenAI(
    api_key=OPENAI_API_KEY
    )

    response = client.chat.completions.create(
    model = "gpt-4o-mini",
    messages =[
        {"role": "system", "content": "You are an expert finance assistant"},
        {"role": "user", "content": prompt}
    ]
    )

    message_content = response.choices[0].message.content
    time.sleep(15)

    return message_content

# %%
# Split the unique transactions for multi-threading
unique_transaction_list = transactions_df['Description'].unique().tolist()
NUM_OF_THREADS = 100
df_chunks = np.array_split(unique_transaction_list, NUM_OF_THREADS)

# Kick off a thread for each chunk
with ThreadPoolExecutor(max_workers = NUM_OF_THREADS) as executor:
    futures = [executor.submit(process_chunk, chunk, OPENAI_API_KEY) for chunk in df_chunks]

for future in concurrent.futures.as_completed(futures):
    category_dict.update(future.result())
# Out:
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processing chunk number: 1...
# Processed chunk number: 1Processed chunk number: 1
# Processing time for chunk 2: 15.689648151397705
# Processing chunk number: 2...
#
# Processing time for chunk 2: 15.69260287284851
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.79315996170044
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.795302867889404
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.8045334815979
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.805548429489136
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.807445764541626
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.792574167251587
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.79729962348938
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.789589881896973
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.795166730880737
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.80494236946106
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.800302505493164
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.816342115402222
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.817972183227539
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.810829162597656
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.805620193481445
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.6377592086792
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.809949398040771
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.811233043670654
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.853668451309204
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.857243776321411
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.692535638809204
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.702824354171753
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.701228141784668
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.70561408996582
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.702799797058105
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.6902174949646
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.770341396331787
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.591816902160645
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.73123288154602
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.73904275894165
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.726802349090576
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.607275009155273
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.750534772872925
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.744398355484009
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.904550075531006
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.564637184143066
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.771404027938843
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.62564992904663
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.773098945617676
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.93664264678955
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.787820100784302
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15.66427993774414
# Processing chunk number: 2...
# Processed chunk number: 1
# Processing time for chunk 2: 15
# Processing chunk number: 11...
# Processed chunk number: 10
# Processing time for chunk 11: 15.51181960105896
# Processed chunk number: 10
# Processing time for chunk 11: 15.545888662338257
# Processed chunk number: 10
# Processing time for chunk 11: 15.35938048362732
# Processed chunk number: 10
# Processing time for chunk 11: 15.510915279388428
# Processed chunk number: 10
# Processing time for chunk 11: 15.389883279800415
# Processed chunk number: 10
# Processing time for chunk 11: 15.436241626739502
# Processed chunk number: 10
# Processing time for chunk 11: 15.513375282287598
# Processed chunk number: 10
# Processing time for chunk 11: 15.667999029159546
# Processed chunk number: 10
# Processing time for chunk 11: 15.422353506088257
# Processed chunk number: 10
# Processing time for chunk 11: 15.3916015625
# Processed chunk number: 10
# Processing time for chunk 11: 15.346112251281738
# Processing chunk number: 11...
# Processed chunk number: 10
# Processing time for chunk 11: 15.469056844711304
# Processed chunk number: 10
# Processing time for chunk 11: 15.469701290130615
# Processed chunk number: 10
# Processing time for chunk 11: 15.439256429672241
# Processed chunk number: 10
# Processing time for chunk 11: 15.376599073410034
# Processed chunk number: 10
# Processing time for chunk 11: 15.438558578491211
# Processed chunk number: 10
# Processing time for chunk 11: 15.376334428787231
# Processed chunk number: 10
# Processing time for chunk 11: 15.500254154205322
# Processed chunk number: 10
# Processing time for chunk 11: 15.407732486724854
# Processing chunk number: 11...
# Processed chunk number: 10
# Processing time for chunk 11: 15.50135350227356
# Processed chunk number: 10
# Processing time for chunk 11: 15.577768325805664
# Processed chunk number: 10
# Processing time for chunk 11: 15.499900341033936
# Processed chunk number: 10
# Processing time for chunk 11: 15.531165599822998
# Processed chunk number: 10
# Processing time for chunk 11: 15.546399354934692
# Processing chunk number: 11...
# Processed chunk number: 10
# Processing time for chunk 11: 15.484450817108154
# Processed chunk number: 10
# Processing time for chunk 11: 15.423524618148804
# Processed chunk number: 10
# Processing time for chunk 11: 15.422522068023682
# Processed chunk number: 10
# Processing time for chunk 11: 15.543068408966064
# Processed chunk number: 10
# Processing time for chunk 11: 15.591751337051392
# Processed chunk number: 10
# Processing time for chunk 11: 15.437176704406738
# Processed chunk number: 10
# Processing time for chunk 11: 15.391402006149292
# Processed chunk number: 10
# Processing time for chunk 11: 15.49889326095581
# Processing chunk number: 11...
# Processed chunk number: 10
# Processing time for chunk 11: 15.607589960098267
# Processed chunk number: 10
# Processing time for chunk 11: 15.407079696655273
# Processed chunk number: 10
# Processing time for chunk 11: 15.407583951950073
# Processed chunk number: 10
# Processing time for chunk 11: 15.5013906955719
# Processing chunk number: 11...
# Processed chunk number: 10
# Processing time for chunk 11: 15.653043985366821
# Processed chunk number: 10
# Processing time for chunk 11: 15.561714887619019
# Processed chunk number: 10
# Processing time for chunk 11: 15.608870029449463
# Processed chunk number: 10
# Processing time for chunk 11: 15.57910704612732
# Processed chunk number: 10
# Processing time for chunk 11: 15.564163446426392
# Processed chunk number: 10
# Processing time for chunk 11: 15.6872079372406
# Processing chunk number: 11...
# Processed chunk number: 10
# Processing time for chunk 11: 15.367496490478516
# Processed chunk number: 10
# Processing time for chunk 11: 15.809899091720581
# Processing chunk number: 11...
# Processed chunk number: 10
# Processing time for chunk 11: 15.3674476146698
# Processed chunk number: 10
# Processing time for chunk 11: 15.444577932357788
# Processed chunk number: 10
# Processing time for chunk 11: 15.504750728607178
# Processed chunk number: 10
# Processing time for chunk 11: 15.517879962921143
# Processed chunk number: 10
# Processing time for chunk 11: 15.748460054397583
# Processed chunk number: 10
# Processing time for chunk 11: 15.520530462265015
# Processed chunk number: 10
# Processing time for chunk 11: 15.857097864151001
# Processed chunk number: 10
# Processing time for chunk 11: 15.49101972579956
# Processed chunk number: 10
# Processing time for chunk 11: 15.446541786193848
# Processed chunk number: 10
# Processing time for chunk 11: 15.338067293167114
# Processed chunk number: 10
# Processing time for chunk 11: 15.415939569473267
# Processed chunk number: 10
# Processing time for chunk 11: 15.526434421539307
# Processed chunk number: 10
# Processing time for chunk 11: 15.541161060333252
# Processed chunk number: 10
# Processing time for chunk 11: 15.52484130859375
# Processed chunk number: 10
# Processing time for chunk 11: 15.35851263999939
# Processing chunk number: 11...
# Processed chunk number: 10
# Processing time for chunk 11: 15.421144962310791
# Processed chunk number: 10Processed chunk number: 10
# Processing time for chunk 11: 15.404810190200806
#
# Processing time for chunk 11: 15.576159000396729
# Processed chunk number: 10
# Processing time for chunk 11: 15.3905770778656
# Processed chunk number: 10
# Processing time for chunk 11: 15.360698461532593
# Processed chunk number: 10
# Processing time for chunk 11: 15.453860759735107
# Processed chunk number: 10
# Processing time for chunk 11: 15.840660333633423
# Processed chunk number: 10
# Processing time for chunk 11: 15.484307765960693
# Processed chunk number: 10
# Processing time for chunk 11: 15.407405853271484
# Processed chunk number: 10
# Processing time for chunk 11: 15.563968420028687
# Processed chunk number: 10
# Processing time for chunk 11: 15.503910064697266
# Processed chunk number: 10
# Processing time for chunk 11: 15.555953979492188
# Processed chunk number: 10
# Processing time for chunk 11: 15.407403469085693
# Processed chunk number: 10
# Processing time for chunk 11: 15.329787015914917
# Processed chunk number: 10
# Processing time for chunk 11: 15.377602577209473
# Processing chunk number: 11...
# Processed chunk number: 10
# Processing time for chunk 11: 15.48335576057434
# Processed chunk number: 10
# Processing time for chunk 11: 15.407367467880249
# Processing chunk number: 11...
# Processed chunk number: 11
# Processing time for chunk 12: 15.485971689224243
# Processed chunk number: 11
# Processing time for chunk 12: 15.501678466796875
# Processed chunk number: 11
# Processing time for chunk 12: 15.486258506774902
# Processed chunk number: 11
# Processing time for chunk 12: 15.53341031074524
# Processed chunk number: 11
# Processing time for chunk 12: 15.473163604736328
# Processed chunk number: 11
# Processing time for chunk 12: 15.549680948257446
# Processed chunk number: 11
# Processing time for chunk 12: 15.476057767868042
# Processed chunk number: 11
# Processing time for chunk 12: 15.658469438552856
# Processed chunk number: 11
# Processing time for chunk 12: 15.488434553146362
# Processed chunk number: 11
# Processing time for chunk 12: 15.6584312915802
# Processed chunk number: 11
# Processing time for chunk 12: 15.473724603652954
# Processed chunk number: 11
# Processing time for chunk 12: 15.44155740737915
# Processed chunk number: 11
# Processing time for chunk 12: 15.427343130111694
# Processed chunk number: 11
# Processing time for chunk 12: 15.439757347106934
# Processed chunk number: 11
# Processing time for chunk 12: 15.332783937454224
# Processed chunk number: 11
# Processing time for chunk 12: 15.47045612335205
# Processed chunk number: 11
# Processing time for chunk 12: 15.426187992095947
# Processed chunk number: 11
# Processing time for chunk 12: 15.440283060073853
# Processed chunk number: 11
# Processing time for chunk 12: 15.595867156982422
# Processed chunk number: 11
# Processing time for chunk 12: 15.45448613166809
# Processed chunk number: 11
# Processing time for chunk 12: 15.532912492752075
# Processed chunk number: 11
# Processing time for chunk 12: 15.4913489818573

# %%
def create_category_column(description, category_dict):
    category = category_dict[description]
    return category

# %%
# Apply categorization to each transaction
transactions_df['Category'] = transactions_df.apply(
    lambda row: create_category_column(
        description=row['Description'],
        category_dict=category_dict),
        axis=1
)

# Define file path to save categorized transactions
new_file_path = str(transaction_folder / 'categorized_transactions.csv')

# Save the updated file
transactions_df.to_csv(new_file_path, index = False)
